# %%
import pandas as pd
from fbprophet import Prophet
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
confirmed = pd.read_csv('time_series_19-covid-Confirmed.csv')
deaths = pd.read_csv('time_series_19-covid-Deaths.csv')
recovered = pd.read_csv('time_series_19-covid-Recovered.csv')

# %%
country = "Italy"

# %%
conf = confirmed[confirmed['Country/Region']==country].iloc[:,4:].sum(axis=0).reset_index().rename(columns={"index":"ds", 0:"y"})
death = deaths[deaths['Country/Region']==country].iloc[:,4:].sum(axis=0).reset_index().rename(columns={"index":"ds", 0:"y"})
rec = recovered[recovered['Country/Region']==country].iloc[:,4:].sum(axis=0).reset_index().rename(columns={"index":"ds", 0:"y"})

# %%
conf
# Out:
#          ds    y
# 0   1/22/20    0
# 1   1/23/20    0
# 2   1/24/20    0
# 3   1/25/20    0
# 4   1/26/20    0
# 5   1/27/20    0
# 6   1/28/20    0
# 7   1/29/20    0
# 8   1/30/20    0
# 9   1/31/20    2
# 10   2/1/20    2
# 11   2/2/20    2
# 12   2/3/20    2
# 13   2/4/20    2
# 14   2/5/20    2
# 15   2/6/20    2
# 16   2/7/20    3
# 17   2/8/20    3
# 18   2/9/20    3
# 19  2/10/20    3
# 20  2/11/20    3
# 21  2/12/20    3
# 22  2/13/20    3
# 23  2/14/20    3
# 24  2/15/20    3
# 25  2/16/20    3
# 26  2/17/20    3
# 27  2/18/20    3
# 28  2/19/20    3
# 29  2/20/20    3
# 30  2/21/20   20
# 31  2/22/20   62
# 32  2/23/20  155
# 33  2/24/20  229
# 34  2/25/20  322
# 35  2/26/20  453
# 36  2/27/20  655
# 37  2/28/20  888
